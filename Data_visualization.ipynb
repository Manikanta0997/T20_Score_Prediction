# %%
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pickle.load(open('dataset_level3.pkl','rb'))

# %%
df.head()
# Out:
#       batting_team bowling_team        city  current_score  balls_left  \
# 69632    Sri Lanka     Pakistan      Mirpur            123          20
# 2354       England  New Zealand    Hamilton            165          13
# 39892    Sri Lanka  New Zealand  Nottingham             87          50
# 6202     Sri Lanka        India     Colombo            118          39
# 59768     Pakistan   Bangladesh      Mirpur            113          40
#
#        wickets_left       crr  last_five  runs_x
# 69632             8  7.380000       36.0     150
# 2354              5  9.252336       45.0     194
# 39892             7  7.457143       33.0     158
# 6202              5  8.740741       38.0     152
# 59768             7  8.475000       45.0     190

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr());

# %%
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='batting_team', data=df);

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='bowling_team', data=df);

# %%
plt.figure(figsize=(50, 16))
sns.countplot(x='city', data=df);
